# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from collections import Counter
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))
lemm = WordNetLemmatizer()
import numpy as np
from collections import Counter
lines=100000

# %%
data = pd.read_excel(r"C:\Users\PIYUSH\Downloads\AG\training_set_rel3.xlsx",sheet_name="training_set")

# %%
data
# Out:
#        essay_id  essay_set                                              essay  \
# 0             1          1  Dear local newspaper, I think effects computer...
# 1             2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2             3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3             4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4             5          1  Dear @LOCATION1, I know having computers has a...
# 5             6          1  Dear @LOCATION1, I think that computers have a...
# 6             7          1  Did you know that more and more people these d...
# 7             8          1  @PERCENT1 of people agree that computers make ...
# 8             9          1  Dear reader, @ORGANIZATION1 has had a dramatic...
# 9            10          1  In the @LOCATION1 we have the technology of a ...
# 10           11          1  Dear @LOCATION1, @CAPS1 people acknowledge the...
# 11           12          1  Dear @CAPS1 @CAPS2 I feel that computers do ta...
# 12           13          1  Dear local newspaper I raed ur argument on the...
# 13           14          1  My three detaileds for this news paper article...
# 14           15          1  Dear, In this world today we should have every...
# 15           16          1  Dear @ORGANIZATION1, The computer blinked to l...
# 16           17          1  Dear Local Newspaper, I belive that computers ...
# 17           18          1  Dear Local Newspaper, I must admit that the ex...
# 18           19          1  I aegre waf the evansmant ov tnachnolage. The ...
# 19           20          1  Well computers can be a good or a bad thing. I...
# 20           21          1  Dear @CAPS1 of the @CAPS2 @CAPS3 daily, I am w...
# 21           22          1  Dear local Newspaper @CAPS1 a take all your co...
# 22           23          1  Dear local newspaper, @CAPS1 you ever see a ch...
# 23           24          1  Dear local newspaper, I've heard that not many...
# 24           25          1  Dear @CAPS1, @CAPS2 off, I beileve that comput...
# 25           26          1  Do you think that computers are useless? Or do...
# 26           27          1  Computers a good because you can get infermati...
# 27           28          1  Dear Newspaper, Computers are high tec and hav...
# 28           29          1  Dear local newspaper, @CAPS1 people throughout...
# 29           30          1  Dear Newspaper People, I think that computers ...
# ...         ...        ...                                                ...
# 12948     21592          8   We all understand the benefits of laughter. L...
# 12949     21594          8        It was midsummer, and i could feel the c...
# 12950     21595          8   Have you ever experienced a time with your fr...
# 12951     21596          8   I woke up just like any other day happy yet l...
# 12952     21598          8   Laughter is an important part of my life, eit...
# 12953     21599          8   I sat at the table, speechless, as they told ...
# 12954     21601          8   As I remember back, it was @DATE1. It was a h...
# 12955     21603          8   Those eyes, it was like I was looking out int...
# 12956     21604          8  Some say that laugh is the common language bet...
# 12957     21605          8   Laughter is an integral element to many situa...
# 12958     21606          8  One time I was at my friend @PERSON1's house, ...
# 12959     21607          8   LAUGHTER @CAPS1 knows that laughter is a heal...
# 12960     21608          8  One thing that people in the world love to do ...
# 12961     21609          8   Laughter, to me, is an important aspect of my...
# 12962     21610          8   People always say that the worst parts of lif...
# 12963     21611          8   Why is it that people can look back at someth...
# 12964     21613          8   Before my best friend moved away, we would st...
# 12965     21615          8                                @ORGANIZATION1  ...
# 12966     21617          8   Morose and somnolent, I woke up. I woke up to...
# 12967     21618          8   A while back my mom had decided to send me to...
# 12968     21619          8                              I dont like computers
# 12969     21620          8   Everyone knows how important a laugh can be. ...
# 12970     21621          8   Laughter is an important part of my family. W...
# 12971     21623          8   laughter is an important part of any kind of ...
# 12972     21624          8  Sometime ago on a hot @DATE1 day my @NUM1 ,@PE...
# 12973     21626          8   In most stories mothers and daughters are eit...
# 12974     21628          8   I never understood the meaning laughter is th...
# 12975     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
# 12976     21630          8                                 Trippin' on fen...
# 12977     21633          8   Many people believe that laughter can improve...
#
#        rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0                 4.0             4.0             NaN            8.0
# 1                 5.0             4.0             NaN            9.0
# 2                 4.0             3.0             NaN            7.0
# 3                 5.0             5.0             NaN           10.0
# 4                 4.0             4.0             NaN            8.0
# 5                 4.0             4.0             NaN            8.0
# 6                 5.0             5.0             NaN           10.0
# 7                 5.0             5.0             NaN           10.0
# 8                 4.0             5.0             NaN            9.0
# 9                 5.0             4.0             NaN            9.0
# 10                4.0             4.0             NaN            8.0
# 11                4.0             4.0             NaN            8.0
# 12                4.0             3.0             NaN            7.0
# 13                3.0             3.0             NaN            6.0
# 14                3.0             3.0             NaN            6.0
# 15                6.0             6.0             NaN           12.0
# 16                4.0             4.0             NaN            8.0
# 17                4.0             4.0             NaN            8.0
# 18                2.0             2.0             NaN            4.0
# 19                3.0             3.0             NaN            6.0
# 20                4.0             4.0             NaN            8.0
# 21                2.0             1.0             NaN            3.0
# 22                5.0             5.0             NaN           10.0
# 23                6.0             5.0             NaN           11.0
# 24                4.0             4.0             NaN            8.0
# 25                5.0             4.0             NaN            9.0
# 26                2.0             2.0             NaN            4.0
# 27                5.0             4.0             NaN            9.0
# 28                5.0             4.0             NaN            9.0
# 29                4.0             4.0             NaN            8.0
# ...               ...             ...             ...            ...
# 12948            20.0            20.0             NaN           40.0
# 12949            17.0            15.0             NaN           32.0
# 12950            18.0            18.0             NaN           36.0
# 12951            15.0            16.0             NaN           31.0
# 12952            15.0            15.0             NaN           30.0
# 12953            25.0            22.0             NaN           47.0
# 12954            20.0            20.0             NaN           40.0
# 12955            17.0            18.0             NaN           35.0
# 12956            16.0            17.0             NaN           33.0
# 12957            18.0            18.0             NaN           36.0
# 12958            20.0            16.0             NaN           36.0
# 12959            25.0            23.0             NaN           48.0
# 12960            20.0            20.0             NaN           40.0
# 12961            20.0            20.0             NaN           40.0
# 12962            20.0            20.0             NaN           40.0
# 12963            22.0            20.0             NaN           42.0
# 12964            20.0            19.0            40.0           40.0
# 12965            15.0            17.0             NaN           32.0
# 12966            18.0            18.0             NaN           36.0
# 12967            20.0            19.0            40.0           40.0
# 12968             5.0             5.0             NaN           10.0
# 12969            18.0            15.0             NaN           33.0
# 12970            24.0            20.0             NaN           44.0
# 12971            18.0            17.0             NaN           35.0
# 12972            17.0            15.0            30.0           30.0
# 12973            17.0            18.0             NaN           35.0
# 12974            15.0            17.0             NaN           32.0
# 12975            20.0            26.0            40.0           40.0
# 12976            20.0            20.0             NaN           40.0
# 12977            20.0            20.0             NaN           40.0
#
#        rater1_domain2  rater2_domain2  domain2_score      ...        \
# 0                 NaN             NaN            NaN      ...
# 1                 NaN             NaN            NaN      ...
# 2                 NaN             NaN            NaN      ...
# 3                 NaN             NaN            NaN      ...
# 4                 NaN             NaN            NaN      ...
# 5                 NaN             NaN            NaN      ...
# 6                 NaN             NaN            NaN      ...
# 7                 NaN             NaN            NaN      ...
# 8                 NaN             NaN            NaN      ...
# 9                 NaN             NaN            NaN      ...
# 10                NaN             NaN            NaN      ...
# 11                NaN             NaN            NaN      ...
# 12                NaN             NaN            NaN      ...
# 13                NaN             NaN            NaN      ...
# 14                NaN             NaN            NaN      ...
# 15                NaN             NaN            NaN      ...
# 16                NaN             NaN            NaN      ...
# 17                NaN             NaN            NaN      ...
# 18                NaN             NaN            NaN      ...
# 19                NaN             NaN            NaN      ...
# 20                NaN             NaN            NaN      ...
# 21                NaN             NaN            NaN      ...
# 22                NaN             NaN            NaN      ...
# 23                NaN             NaN            NaN      ...
# 24                NaN             NaN            NaN      ...
# 25                NaN             NaN            NaN      ...
# 26                NaN             NaN            NaN      ...
# 27                NaN             NaN            NaN      ...
# 28                NaN             NaN            NaN      ...
# 29                NaN             NaN            NaN      ...
# ...               ...             ...            ...      ...
# 12948             NaN             NaN            NaN      ...
# 12949             NaN             NaN            NaN      ...
# 12950             NaN             NaN            NaN      ...
# 12951             NaN             NaN            NaN      ...
# 12952             NaN             NaN            NaN      ...
# 12953             NaN             NaN            NaN      ...
# 12954             NaN             NaN            NaN      ...
# 12955             NaN             NaN            NaN      ...
# 12956             NaN             NaN            NaN      ...
# 12957             NaN             NaN            NaN      ...
# 12958             NaN             NaN            NaN      ...
# 12959             NaN             NaN            NaN      ...
# 12960             NaN             NaN            NaN      ...
# 12961             NaN             NaN            NaN      ...
# 12962             NaN             NaN            NaN      ...
# 12963             NaN             NaN            NaN      ...
# 12964             NaN             NaN            NaN      ...
# 12965             NaN             NaN            NaN      ...
# 12966             NaN             NaN            NaN      ...
# 12967             NaN             NaN            NaN      ...
# 12968             NaN             NaN            NaN      ...
# 12969             NaN             NaN            NaN      ...
# 12970             NaN             NaN            NaN      ...
# 12971             NaN             NaN            NaN      ...
# 12972             NaN             NaN            NaN      ...
# 12973             NaN             NaN            NaN      ...
# 12974             NaN             NaN            NaN      ...
# 12975             NaN             NaN            NaN      ...
# 12976             NaN             NaN            NaN      ...
# 12977             NaN             NaN            NaN      ...
#
#        rater2_trait3  rater2_trait4  rater2_trait5  rater2_trait6  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# 5                NaN            NaN            NaN            NaN
# 6                NaN            NaN            NaN            NaN
# 7                NaN            NaN            NaN            NaN
# 8                NaN            NaN            NaN            NaN
# 9                NaN            NaN            NaN            NaN
# 10               NaN            NaN            NaN            NaN
# 11               NaN            NaN            NaN            NaN
# 12               NaN            NaN            NaN            NaN
# 13               NaN            NaN            NaN            NaN
# 14               NaN            NaN            NaN            NaN
# 15               NaN            NaN            NaN            NaN
# 16               NaN            NaN            NaN            NaN
# 17               NaN            NaN            NaN            NaN
# 18               NaN            NaN            NaN            NaN
# 19               NaN            NaN            NaN            NaN
# 20               NaN            NaN            NaN            NaN
# 21               NaN            NaN            NaN            NaN
# 22               NaN            NaN            NaN            NaN
# 23               NaN            NaN            NaN            NaN
# 24               NaN            NaN            NaN            NaN
# 25               NaN            NaN            NaN            NaN
# 26               NaN            NaN            NaN            NaN
# 27               NaN            NaN            NaN            NaN
# 28               NaN            NaN            NaN            NaN
# 29               NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 12948            4.0            4.0            4.0            4.0
# 12949            3.0            3.0            3.0            3.0
# 12950            4.0            4.0            4.0            4.0
# 12951            4.0            4.0            4.0            3.0
# 12952            3.0            4.0            3.0            3.0
# 12953            5.0            5.0            4.0            4.0
# 12954            4.0            4.0            4.0            4.0
# 12955            4.0            4.0            4.0            3.0
# 12956            4.0            3.0            3.0            3.0
# 12957            4.0            4.0            4.0            4.0
# 12958            4.0            4.0            4.0            3.0
# 12959            5.0            4.0            5.0            4.0
# 12960            4.0            4.0            4.0            4.0
# 12961            4.0            4.0            4.0            4.0
# 12962            5.0            4.0            4.0            4.0
# 12963            4.0            4.0            4.0            4.0
# 12964            4.0            4.0            4.0            4.0
# 12965            4.0            4.0            3.0            3.0
# 12966            4.0            4.0            4.0            3.0
# 12967            4.0            4.0            4.0            4.0
# 12968            1.0            1.0            1.0            1.0
# 12969            4.0            4.0            3.0            3.0
# 12970            4.0            4.0            4.0            4.0
# 12971            4.0            3.0            3.0            3.0
# 12972            4.0            4.0            3.0            3.0
# 12973            4.0            4.0            4.0            3.0
# 12974            4.0            4.0            4.0            3.0
# 12975            5.0            5.0            5.0            5.0
# 12976            4.0            4.0            4.0            4.0
# 12977            4.0            4.0            4.0            4.0
#
#        rater3_trait1  rater3_trait2  rater3_trait3  rater3_trait4  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# 5                NaN            NaN            NaN            NaN
# 6                NaN            NaN            NaN            NaN
# 7                NaN            NaN            NaN            NaN
# 8                NaN            NaN            NaN            NaN
# 9                NaN            NaN            NaN            NaN
# 10               NaN            NaN            NaN            NaN
# 11               NaN            NaN            NaN            NaN
# 12               NaN            NaN            NaN            NaN
# 13               NaN            NaN            NaN            NaN
# 14               NaN            NaN            NaN            NaN
# 15               NaN            NaN            NaN            NaN
# 16               NaN            NaN            NaN            NaN
# 17               NaN            NaN            NaN            NaN
# 18               NaN            NaN            NaN            NaN
# 19               NaN            NaN            NaN            NaN
# 20               NaN            NaN            NaN            NaN
# 21               NaN            NaN            NaN            NaN
# 22               NaN            NaN            NaN            NaN
# 23               NaN            NaN            NaN            NaN
# 24               NaN            NaN            NaN            NaN
# 25               NaN            NaN            NaN            NaN
# 26               NaN            NaN            NaN            NaN
# 27               NaN            NaN            NaN            NaN
# 28               NaN            NaN            NaN            NaN
# 29               NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 12948            NaN            NaN            NaN            NaN
# 12949            NaN            NaN            NaN            NaN
# 12950            NaN            NaN            NaN            NaN
# 12951            NaN            NaN            NaN            NaN
# 12952            NaN            NaN            NaN            NaN
# 12953            NaN            NaN            NaN            NaN
# 12954            NaN            NaN            NaN            NaN
# 12955            NaN            NaN            NaN            NaN
# 12956            NaN            NaN            NaN            NaN
# 12957            NaN            NaN            NaN            NaN
# 12958            NaN            NaN            NaN            NaN
# 12959            NaN            NaN            NaN            NaN
# 12960            NaN            NaN            NaN            NaN
# 12961            NaN            NaN            NaN            NaN
# 12962            NaN            NaN            NaN            NaN
# 12963            NaN            NaN            NaN            NaN
# 12964            4.0            4.0            4.0            4.0
# 12965            NaN            NaN            NaN            NaN
# 12966            NaN            NaN            NaN            NaN
# 12967            4.0            4.0            4.0            4.0
# 12968            NaN            NaN            NaN            NaN
# 12969            NaN            NaN            NaN            NaN
# 12970            NaN            NaN            NaN            NaN
# 12971            NaN            NaN            NaN            NaN
# 12972            3.0            3.0            4.0            4.0
# 12973            NaN            NaN            NaN            NaN
# 12974            NaN            NaN            NaN            NaN
# 12975            4.0            4.0            4.0            4.0
# 12976            NaN            NaN            NaN            NaN
# 12977            NaN            NaN            NaN            NaN
#
#        rater3_trait5  rater3_trait6
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# 5                NaN            NaN
# 6                NaN            NaN
# 7                NaN            NaN
# 8                NaN            NaN
# 9                NaN            NaN
# 10               NaN            NaN
# 11               NaN            NaN
# 12               NaN            NaN
# 13               NaN            NaN
# 14               NaN            NaN
# 15               NaN            NaN
# 16               NaN            NaN
# 17               NaN            NaN
# 18               NaN            NaN
# 19               NaN            NaN
# 20               NaN            NaN
# 21               NaN            NaN
# 22               NaN            NaN
# 23               NaN            NaN
# 24               NaN            NaN
# 25               NaN            NaN
# 26               NaN            NaN
# 27               NaN            NaN
# 28               NaN            NaN
# 29               NaN            NaN
# ...              ...            ...
# 12948            NaN            NaN
# 12949            NaN            NaN
# 12950            NaN            NaN
# 12951            NaN            NaN
# 12952            NaN            NaN
# 12953            NaN            NaN
# 12954            NaN            NaN
# 12955            NaN            NaN
# 12956            NaN            NaN
# 12957            NaN            NaN
# 12958            NaN            NaN
# 12959            NaN            NaN
# 12960            NaN            NaN
# 12961            NaN            NaN
# 12962            NaN            NaN
# 12963            NaN            NaN
# 12964            4.0            4.0
# 12965            NaN            NaN
# 12966            NaN            NaN
# 12967            4.0            4.0
# 12968            NaN            NaN
# 12969            NaN            NaN
# 12970            NaN            NaN
# 12971            NaN            NaN
# 12972            3.0            3.0
# 12973            NaN            NaN
# 12974            NaN            NaN
# 12975            4.0            4.0
# 12976            NaN            NaN
# 12977            NaN            NaN
#
# [12978 rows x 28 columns]

# %%
>>> from nltk.corpus import stopwords
>>> stop = set(stopwords.words('english'))

# %% [markdown]
# lexicon=[]
# for i in data["essay"]:
#     all_words=word_tokenize(i)
#     #all_words=[i for i in all_words if i not in stop]
#     all_words=[lemm.lemmatize(j.lower()) for j in all_words]
#     lexicon.append(all_words)

# %% [markdown]
# data["word_count"]=pd.Series(np.random.randn(data.shape[0]), index=data.index)

# %% [markdown]
# for i in range(data.shape[0]):
#     data["word_count"].iloc[i]=len(lexicon[i])

# %%
df = pd.read_pickle(r"C:\Users\PIYUSH\Desktop\essay.pkl")

# %%
del df["vocab_count"]

# %%
def vocab():
    lexicon=[]
    for i in data["essay"]:
        all_words=word_tokenize(i)
        all_words=[i for i in all_words if i not in stop]
        all_words=[word.lower() for word in all_words if word.isalpha()]
        all_words=[lemm.lemmatize(j.lower()) for j in all_words]
        lexicon.append(all_words)
    data["vocab_count"]=pd.Series(np.random.randn(data.shape[0]), index=data.index)
    for i in range(data.shape[0]):
        data["vocab_count"].iloc[i]=len(set(lexicon[i]))

# %%
vocab()
# Out:
# c:\users\piyush\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0             4.0             4.0             NaN            8.0
# 1             5.0             4.0             NaN            9.0
# 2             4.0             3.0             NaN            7.0
# 3             5.0             5.0             NaN           10.0
# 4             4.0             4.0             NaN            8.0
#
#    rater1_domain2  rater2_domain2  domain2_score     ...       rater2_trait4  \
# 0             NaN             NaN            NaN     ...                 NaN
# 1             NaN             NaN            NaN     ...                 NaN
# 2             NaN             NaN            NaN     ...                 NaN
# 3             NaN             NaN            NaN     ...                 NaN
# 4             NaN             NaN            NaN     ...                 NaN
#
#    rater2_trait5  rater2_trait6  rater3_trait1  rater3_trait2  rater3_trait3  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait4  rater3_trait5  rater3_trait6  vocab_count
# 0            NaN            NaN            NaN        103.0
# 1            NaN            NaN            NaN        129.0
# 2            NaN            NaN            NaN         92.0
# 3            NaN            NaN            NaN        169.0
# 4            NaN            NaN            NaN        131.0
#
# [5 rows x 29 columns]

# %%
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0             4.0             4.0             NaN            8.0
# 1             5.0             4.0             NaN            9.0
# 2             4.0             3.0             NaN            7.0
# 3             5.0             5.0             NaN           10.0
# 4             4.0             4.0             NaN            8.0
#
#    rater1_domain2  rater2_domain2  domain2_score     ...      rater2_trait4  \
# 0             NaN             NaN            NaN     ...                NaN
# 1             NaN             NaN            NaN     ...                NaN
# 2             NaN             NaN            NaN     ...                NaN
# 3             NaN             NaN            NaN     ...                NaN
# 4             NaN             NaN            NaN     ...                NaN
#
#    rater2_trait5  rater2_trait6  rater3_trait1  rater3_trait2  rater3_trait3  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait4  rater3_trait5  rater3_trait6  word_count
# 0            NaN            NaN            NaN       386.0
# 1            NaN            NaN            NaN       464.0
# 2            NaN            NaN            NaN       313.0
# 3            NaN            NaN            NaN       611.0
# 4            NaN            NaN            NaN       517.0
#
# [5 rows x 29 columns]

# %%
data["word_count"]=df["word_count"]

# %%
data.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0             4.0             4.0             NaN            8.0
# 1             5.0             4.0             NaN            9.0
# 2             4.0             3.0             NaN            7.0
# 3             5.0             5.0             NaN           10.0
# 4             4.0             4.0             NaN            8.0
#
#    rater1_domain2  rater2_domain2  domain2_score     ...      rater2_trait5  \
# 0             NaN             NaN            NaN     ...                NaN
# 1             NaN             NaN            NaN     ...                NaN
# 2             NaN             NaN            NaN     ...                NaN
# 3             NaN             NaN            NaN     ...                NaN
# 4             NaN             NaN            NaN     ...                NaN
#
#    rater2_trait6  rater3_trait1  rater3_trait2  rater3_trait3  rater3_trait4  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait5  rater3_trait6  vocab_count  word_count
# 0            NaN            NaN        103.0       386.0
# 1            NaN            NaN        129.0       464.0
# 2            NaN            NaN         92.0       313.0
# 3            NaN            NaN        169.0       611.0
# 4            NaN            NaN        131.0       517.0
#
# [5 rows x 30 columns]

# %%
data.to_pickle(r"C:\Users\PIYUSH\Desktop\essay.pkl")

# %%
data = pd.read_pickle(r"C:\Users\PIYUSH\Desktop\essay.pkl")
data.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0             4.0             4.0             NaN            8.0
# 1             5.0             4.0             NaN            9.0
# 2             4.0             3.0             NaN            7.0
# 3             5.0             5.0             NaN           10.0
# 4             4.0             4.0             NaN            8.0
#
#    rater1_domain2  rater2_domain2  domain2_score     ...      rater2_trait5  \
# 0             NaN             NaN            NaN     ...                NaN
# 1             NaN             NaN            NaN     ...                NaN
# 2             NaN             NaN            NaN     ...                NaN
# 3             NaN             NaN            NaN     ...                NaN
# 4             NaN             NaN            NaN     ...                NaN
#
#    rater2_trait6  rater3_trait1  rater3_trait2  rater3_trait3  rater3_trait4  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait5  rater3_trait6  vocab_count  word_count
# 0            NaN            NaN        103.0       386.0
# 1            NaN            NaN        129.0       464.0
# 2            NaN            NaN         92.0       313.0
# 3            NaN            NaN        169.0       611.0
# 4            NaN            NaN        131.0       517.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## word_count and vocab_count extracted

# %%
def pos():
    lexicon=[]
    noun=0
    verb=0
    adj=0
    adv=0
    n_count=[]
    v_count=[]
    adj_count=[]
    adv_count=[]
    for i in data["essay"]:
        tokenized = sent_tokenize(i)
        for j in tokenized:
            all_words=word_tokenize(j)
            all_words=[k for k in all_words if k not in stop]
            tagged = nltk.pos_tag(all_words)
            for t in tagged:

                if (t[1][0])=='N':
                    noun+=1
                if (t[1][0])=='V':
                    verb+=1
                if (t[1][0])=='R':
                    adv+=1
                if (t[1][0])=='J':
                    adj+=1
        n_count.append(noun)
        v_count.append(verb)
        adj_count.append(adj)
        adv_count.append(adv)
        noun=0
        verb=0
        adv=0
        adj=0
    return  (n_count, v_count, adj_count, adv_count)

# %%
(n_count, v_count, adj_count, adv_count)=pos()

# %%
data["n_count"]=n_count
data["v_count"]=v_count
data["adj_count"]=adj_count
data["adv_count"]=adv_count

# %%
data["essay_set"].iloc[5000]
# Out:
# 3

# %%
data.to_pickle(r"C:\Users\PIYUSH\Desktop\essay.pkl")

# %%
data = pd.read_pickle(r"C:\Users\PIYUSH\Desktop\essay.pkl")

# %% [markdown]
# ### tagging done

# %%
sent=[]
for i in data["essay"]:
    tokenized = sent_tokenize(i)
    sent.append(len(tokenized))

# %%
data["sent_len"]=sent

# %%
data.to_pickle(r"C:\Users\PIYUSH\Desktop\essay.pkl")

# %%
data = pd.read_pickle(r"C:\Users\PIYUSH\Desktop\essay.pkl")
data.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0             4.0             4.0             NaN            8.0
# 1             5.0             4.0             NaN            9.0
# 2             4.0             3.0             NaN            7.0
# 3             5.0             5.0             NaN           10.0
# 4             4.0             4.0             NaN            8.0
#
#    rater1_domain2  rater2_domain2  domain2_score    ...     rater3_trait4  \
# 0             NaN             NaN            NaN    ...               NaN
# 1             NaN             NaN            NaN    ...               NaN
# 2             NaN             NaN            NaN    ...               NaN
# 3             NaN             NaN            NaN    ...               NaN
# 4             NaN             NaN            NaN    ...               NaN
#
#    rater3_trait5  rater3_trait6  vocab_count  word_count  n_count  v_count  \
# 0            NaN            NaN        103.0       386.0       84       39
# 1            NaN            NaN        129.0       464.0      117       61
# 2            NaN            NaN         92.0       313.0       85       33
# 3            NaN            NaN        169.0       611.0      205       63
# 4            NaN            NaN        131.0       517.0      115       50
#
#    adj_count  adv_count  sent_len
# 0         24         11        16
# 1         21         15        20
# 2         21          6        14
# 3         46         14        27
# 4         23         21        30
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Sent count done

# %%
def bow():
    lexicon=[]
    dict1={}
    prev=1
    for i in range(1,9):
        dict1[i]=["student"]
    for i,j in enumerate(data["essay_set"]):
        tokenized=sent_tokenize(data["essay"].iloc[i])
        for k in tokenized:
            all_words=word_tokenize(k)
            all_words=[i for i in all_words if i not in stop]
            tagged = nltk.pos_tag(all_words)
            all_words=[i[0] for i in tagged if (i[1][0]=="N" or i[1][0]=="V"  or i[1][0]=="J")]
            all_words=[lemm.lemmatize(j.lower()) for j in all_words]
            dict1[j]+=all_words
    return dict1

# %%
dict=bow()

# %%
def poping(w_counts):
    w_counts.pop('@',None)
    w_counts.pop('CAPS1',None)
    w_counts.pop('CAPS2',None)
    w_counts.pop('CAPS3',None)
    w_counts.pop('CAPS4',None)
    w_counts.pop('CAPS5',None)
    w_counts.pop('NUM1',None)
    w_counts.pop('”',None)
    w_counts.pop('“',None)
    w_counts.pop('’',None)

# %%
w_counts = Counter(dict[1])
poping(w_counts)
print(w_counts)
ls=[]
l2=[]
for i in w_counts:
    ls.append(w_counts[i])
b=max(ls)
print(b)
for w in w_counts:
    if b > w_counts[w] > b-3000:
        l2.append(w)
# Out:
# Counter({'people': 9520, 'computer': 9101, 'computers': 8392, 'time': 4014, 'get': 2867, 'friends': 2789, 'go': 2583, 'family': 2480, 'use': 2418, 'Computers': 2239, 'help': 2213, 'think': 2171, 'talk': 1886, 'things': 1843, 'good': 1806, 'know': 1781, 'many': 1755, 'learn': 1729, 'online': 1611, 'need': 1514, 'way': 1490, 'world': 1428, 'see': 1421, 'life': 1315, 'want': 1309, 'internet': 1307, 'day': 1301, 'information': 1301, 'reason': 1243, 'society': 1230, 'much': 1224, 'school': 1211, 'Dear': 1175, 'kids': 1151, 'make': 1141, 'spend': 1141, 'find': 1124, 'thing': 1053, 'games': 1049, 'going': 1042, 'effect': 1029, 'say': 1018, 'ORGANIZATION1': 1016, 'great': 1010, 'bad': 981, 'work': 979, 'new': 889, 'play': 831, 'positive': 830, 'places': 826, 'using': 825, 'LOCATION1': 815, 'technology': 799, 'People': 799, 'lot': 798, 'example': 796, 'look': 792, 'something': 788, 'coordination': 787, 'important': 756, 'take': 740, 'exercise': 732, 'person': 705, 'MONTH1': 701, 'fun': 700, 'nature': 686, 'believe': 684, 'keep': 664, 'type': 660, 'websites': 650, 'used': 617, 'hand-eye': 614, 'able': 611, 'give': 585, 'home': 581, 'research': 575, 'reasons': 574, 'spending': 573, 'homework': 571, 'stay': 571, 'getting': 565, 'friend': 564, 'PERCENT1': 554, 'someone': 545, 'different': 524, 'helps': 521, 'children': 505, 'live': 504, 'students': 504, 'CAPS6': 502, 'communicate': 497, 'talking': 496, 'ways': 493, 'hand': 486, 'outside': 486, 'PERSON1': 479, 'less': 475, 'dont': 473, 'facebook': 472, 'lives': 470, 'teach': 470, 'effects': 456, 'playing': 455, 'NUM2': 450, 'allow': 449, 'anything': 448, 'hours': 443, 'agree': 442, 'benefit': 438, 'everyone': 438, 'social': 420, 'helpful': 415, 'place': 407, 'become': 407, 'easier': 391, 'let': 390, 'exercising': 388, 'said': 385, "'re": 385, 'others': 380, 'got': 377, 'opinion': 373, 'game': 372, 'book': 371, 'paper': 371, 'eye': 369, 'learning': 365, 'communication': 363, 'newspaper': 361, 'conclusion': 360, "'s": 358, 'local': 353, 'negative': 353, 'money': 352, 'Newspaper': 348, 'last': 348, 'touch': 347, 'enjoy': 344, 'video': 343, 'everyday': 341, 'looking': 341, 'phone': 340, 'easy': 340, 'come': 338, 'read': 336, 'email': 335, 'CAPS7': 333, 'ability': 331, 'done': 330, 'health': 330, 'parents': 325, 'news': 320, 'chat': 319, 'DATE1': 318, 'interact': 316, 'feel': 314, 'country': 314, 'job': 312, 'everything': 311, 'Many': 309, 'better': 305, 'hope': 305, 'books': 304, 'house': 300, 'LOCATION2': 298, 'project': 298, 'cause': 297, 'jobs': 297, 'problem': 297, 'days': 294, 'write': 293, 'Do': 290, 'ORGANIZATION2': 290, 'reading': 290, 'screen': 289, 'search': 289, 'today': 288, 'website': 288, 'says': 288, 'writing': 287, 'adults': 285, 'big': 284, 'sites': 282, 'old': 281, 'tell': 280, 'long': 276, 'pictures': 274, 'enjoying': 270, 'skills': 267, 'allows': 267, 'years': 265, 'stop': 265, 'sitting': 261, 'made': 260, 'healthy': 255, 'gives': 254, 'typing': 254, 'best': 253, 'show': 251, "'m": 250, 'makes': 250, 'meet': 249, 'right': 249, 'start': 249, 'like': 248, 'child': 247, 'useful': 246, 'first': 245, 'little': 240, 'benefits': 237, 'alot': 236, 'watch': 235, 'sit': 233, 'addicted': 233, 'affect': 232, 'send': 232, 'interacting': 230, 'sports': 229, 'enough': 227, 'myspace': 226, 'NUM3': 226, 'PERCENT2': 226, 'put': 226, 'library': 225, 'education': 225, 'families': 224, 'part': 224, 'second': 223, 'nothing': 222, 'stuff': 220, 'eyes': 220, 'love': 219, 'buy': 217, 'letter': 217, 'face': 216, 'year': 216, 'found': 215, 'weight': 215, 'web': 210, 'CAPS8': 209, 'Most': 208, 'real': 207, 'save': 206, 'making': 202, 'contact': 202, 'next': 202, 'fact': 200, 'PERSON2': 200, 'projects': 200, 'went': 199, 'whole': 199, 'taking': 198, 'problems': 198, 'least': 197, 'remember': 193, 'videos': 189, 'needed': 188, 'student': 185, 'topic': 184, 'understand': 183, 'study': 183, 'sure': 181, 'instant': 181, 'spent': 180, 'mom': 179, 'check': 179, 'music': 178, 'times': 177, 'needs': 177, 'hour' ...
# 9520

# %%
l2
# Out:
# []

# %%
l
# Out:
# []
